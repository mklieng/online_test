# %%
a=10

# %%
print(a)
# Out:
# 10

# %%
import time
time.sleep(10)

# %%
pwd
# Out:
# u'C:\\WINDOWS\\system32'

# %%
cd C:\allMyfiles\BOX
# Out:
# C:\allMyfiles\BOX

# %%
pwd
# Out:
# u'C:\\allMyfiles\\BOX'

# %%
ls
# Out:
#  Volume in drive C is OS
#  Volume Serial Number is 2227-BAED
#
#  Directory of C:\allMYfiles\BOX\my_sandbox
#
# 06/05/2014  05:01 PM    <DIR>          .
# 06/05/2014  05:01 PM    <DIR>          ..
# 06/04/2014  04:01 PM    <DIR>          .ipynb_checkpoints
# 02/22/2014  04:34 PM            34,062 Acquired.tif
# 05/22/2014  04:31 PM               763 bsf.sce
# 05/22/2014  04:32 PM             1,185 bsp.sce
# 05/28/2014  06:17 PM               248 bsp_debug.sce
# 06/04/2014  08:29 AM    <DIR>          conversion_JP
# 02/22/2014  05:29 PM            87,230 FFT.tif
# 02/22/2014  10:37 AM            15,935 File_001c.csv
# 05/31/2014  10:29 AM            25,176 File_001c_time_manual.csv
# 05/27/2014  09:27 AM            17,374 File_001cmsdos.csv
# 05/29/2014  09:05 AM            23,457 File_001ctime.csv
# 06/04/2014  01:35 PM    <DIR>          from_start
# 05/28/2014  04:11 PM           531,090 IMG_1071.jpg
# 06/05/2014  04:52 PM    <DIR>          learn_IPyNB
# ...

# %%
from IPython.display import display
from IPython.display import display_pretty, display_html, display_jpeg, display_png, display_json, display_latex, display_svg

# %%
from IPython.display import Image

# %%
i = Image(filename='IMG_1071.jpg')
display(i)

# %%
Image(url='http://python.org/images/python-logo.gif')
# Out:
# <img src="http://python.org/images/python-logo.gif"/>

# %%
from IPython.display import FileLink, FileLinks
FileLink('test.csv')
# Out:
# C:\allMYfiles\BOX\my_sandbox\test.csv

# %%
FileLinks('.')
# Out:
# ./
#   Acquired.tif
#   bsf.sce
#   bsp.sce
#   bsp_debug.sce
#   FFT.tif
#   File_001c.csv
#   File_001cmsdos.csv
#   File_001ctime.csv
#   File_001c_time_manual.csv
#   IMG_1071.jpg
#   test.csv
#   ventplot.sce
#   VolumeFlow.tif
#   WelchPSD.tif
# .\.ipynb_checkpoints/
#   Untitled0-checkpoint.ipynb
# .\Sample Scripts/
#   bsf.m
#   bsp.m
#   ventPlot.m
# .\conversion_JP/
#   CVizData.csv
#   V2C.pl
#   VentData.csv
# .\from_start/
#   001_nobreath.csv
#   001_shortshort.csv
#   001_shortshort2.csv
#   File_001.csv
#   long_edited.csv
#   raw_data_edit_notes.py
#   short.csv
#   shortshort_edited.csv
#   short_edited.csv
#   test.py
#   test2.py
#   testwriter.csv
# .\from_start\copy_of_files/
#   001_nobreath.csv
#   001_short.csv
#   001_shortshort.csv
#   001_shortshort2.csv
#   File_001 - Copy.csv
#   short.csv
# .\from_start\test_sub/
#   movedelBS.py
#   raw_data_edit2.py
#   raw_data_edit3.py
#   raw_data_edit_long.py
#   raw_data_edit_short.py
#   temp2.py
# ...

# %%
# How about embeding IFrame ? Soundcloud ?
HTML("""<iframe width="100%" height="166" scrolling="no" frameborder="no" src="https://w.soundcloud.com/player/?url=https%3A//api.soundcloud.com/tracks/114267245&amp;color=ff6600&amp;auto_play=false&amp;show_artwork=true"></iframe>""")
# Out:
# <iframe width="100%" height="166" scrolling="no" frameborder="no" src="https://w.soundcloud.com/player/?url=https%3A//api.soundcloud.com/tracks/114267245&amp;color=ff6600&amp;auto_play=false&amp;show_artwork=true"></iframe>

# %%
from IPython.display import YouTubeVideo
# a talk about IPython at Sage Days at U. Washington, Seattle.
# Video credit: William Stein.
YouTubeVideo('1j_HxD4iLn8')
# Out:
#         <iframe
#             width="400"
#             height=300"
#             src="https://www.youtube.com/embed/1j_HxD4iLn8"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
from IPython.display import HTML
s = """<table>
<tr>
<th>Header 1</th>
<th>Header 2</th>
</tr>
<tr>
<td>row 1, cell 1</td>
<td>row 1, cell 2</td>
</tr>
<tr>
<td>row 2, cell 1</td>
<td>row 2, cell 2</td>
</tr>
</table>"""

# %%
h = HTML(s); h
# Out:
# <table>
# <tr>
# <th>Header 1</th>
# <th>Header 2</th>
# </tr>
# <tr>
# <td>row 1, cell 1</td>
# <td>row 1, cell 2</td>
# </tr>
# <tr>
# <td>row 2, cell 1</td>
# <td>row 2, cell 2</td>
# </tr>
# </table>

# %%
import pandas

# %%
# %%file data.csv
# Date,Open,High,Low,Close,Volume,Adj Close
# 2012-06-01,569.16,590.00,548.50,584.00,14077000,581.50
# 2012-05-01,584.90,596.76,522.18,577.73,18827900,575.26
# 2012-04-02,601.83,644.00,555.00,583.98,28759100,581.48
# 2012-03-01,548.17,621.45,516.22,599.55,26486000,596.99
# 2012-02-01,458.41,547.61,453.98,542.44,22001000,540.12
# 2012-01-03,409.40,458.24,409.00,456.48,12949100,454.53
# Out:
# Writing data.csv

# %%
df = pandas.read_csv('data.csv')
df
# Out:
#          Date    Open    High     Low   Close    Volume  Adj Close
# 0  2012-06-01  569.16  590.00  548.50  584.00  14077000     581.50
# 1  2012-05-01  584.90  596.76  522.18  577.73  18827900     575.26
# 2  2012-04-02  601.83  644.00  555.00  583.98  28759100     581.48
# 3  2012-03-01  548.17  621.45  516.22  599.55  26486000     596.99
# 4  2012-02-01  458.41  547.61  453.98  542.44  22001000     540.12
# 5  2012-01-03  409.40  458.24  409.00  456.48  12949100     454.53
#
# [6 rows x 7 columns]

# %%
from IPython.display import IFrame
IFrame('http://en.mobile.wikipedia.org/?useformat=mobile', width='100%', height=350)
# Out:
#         <iframe
#             width="100%"
#             height=350"
#             src="http://en.mobile.wikipedia.org/?useformat=mobile"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
from IPython.display import Math
Math(r'F(k) = \int_{-\infty}^{\infty} f(x) e^{2\pi i k} dx')
# Out:
# $$F(k) = \int_{-\infty}^{\infty} f(x) e^{2\pi i k} dx$$

# %%
# %%latex
# \begin{align}
# \nabla \times \vec{\mathbf{B}} -\, \frac1c\, \frac{\partial\vec{\mathbf{E}}}{\partial t} & = \frac{4\pi}{c}\vec{\mathbf{j}} \\
# \nabla \cdot \vec{\mathbf{E}} & = 4 \pi \rho \\
# \nabla \times \vec{\mathbf{E}}\, +\, \frac1c\, \frac{\partial\vec{\mathbf{B}}}{\partial t} & = \vec{\mathbf{0}} \\
# \nabla \cdot \vec{\mathbf{B}} & = 0
# \end{align}
# Out:
# \begin{align}
# \nabla \times \vec{\mathbf{B}} -\, \frac1c\, \frac{\partial\vec{\mathbf{E}}}{\partial t} & = \frac{4\pi}{c}\vec{\mathbf{j}} \\
# \nabla \cdot \vec{\mathbf{E}} & = 4 \pi \rho \\
# \nabla \times \vec{\mathbf{E}}\, +\, \frac1c\, \frac{\partial\vec{\mathbf{B}}}{\partial t} & = \vec{\mathbf{0}} \\
# \nabla \cdot \vec{\mathbf{B}} & = 0
# \end{align}

# %%
p = ProgressBar(1000)
for i in range(1001):
    time.sleep(0.002)
    p.animate(i)

# %%
p = ProgressBar(1000)
for i in range(1001):
    time.sleep(0.002)
    p.animate(i)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-ab25f60c1e9b> in <module>()
#       1
# ----> 2 p = ProgressBar(1000)
#       3 for i in range(1001):
#       4     time.sleep(0.002)
#       5     p.animate(i)
#
# NameError: name 'ProgressBar' is not defined

# %%
from IPython.display import display

from sympy.interactive import printing
printing.init_printing()

from __future__ import division
import sympy as sym
from sympy import *
x, y, z = symbols("x y z")
k, m, n = symbols("k m n", integer=True)
f, g, h = map(Function, 'fgh')

# %%
e = x + 2*y

# %%
eq = ((x+y)**2 * (x+1))
eq
# Out:
#                2
# (x + 1)⋅(x + y)

# %%
import uuid
import time
from IPython.display import HTML, Javascript, display

divid = str(uuid.uuid4())

pb = HTML(
"""
<div style="border: 1px solid black; width:500px">
  <div id="%s" style="background-color:blue; width:0%%">&nbsp;</div>
</div> 
""" % divid)
display(pb)
for i in range(1,101):
    time.sleep(0.1)
    
    display(Javascript("$('div#%s').width('%i%%')" % (divid, i)))
# Out:
# <div style="border: 1px solid black; width:500px">
#   <div id="aad2d7a2-d8a7-4b6b-97d6-aec7308724f2" style="background-color:blue; width:0%">&nbsp;</div>
# </div>

# %%
from __future__ import print_function
import sys, time

class ProgressBar:
    def __init__(self, iterations):
        self.iterations = iterations
        self.prog_bar = '[]'
        self.fill_char = '*'
        self.width = 50
        self.__update_amount(0)

    def animate(self, iter):
        print('\r', self, end='')
        sys.stdout.flush()
        self.update_iteration(iter + 1)

    def update_iteration(self, elapsed_iter):
        self.__update_amount((elapsed_iter / float(self.iterations)) * 100.0)
        self.prog_bar += '  %d of %s complete' % (elapsed_iter, self.iterations)

    def __update_amount(self, new_amount):
        percent_done = int(round((new_amount / 100.0) * 100.0))
        all_full = self.width - 2
        num_hashes = int(round((percent_done / 100.0) * all_full))
        self.prog_bar = '[' + self.fill_char * num_hashes + ' ' * (all_full - num_hashes) + ']'
        pct_place = (len(self.prog_bar) // 2) - len(str(percent_done))
        pct_string = '%d%%' % percent_done
        self.prog_bar = self.prog_bar[0:pct_place] + \
            (pct_string + self.prog_bar[pct_place + len(pct_string):])

    def __str__(self):
        return str(self.prog_bar)

# %%
p = ProgressBar(1000)
for i in range(1001):
    time.sleep(0.002)
    p.animate(i)
# Out:
#  [                       0%                       ]
#  [                       0%                       ]  1 of 1000 complete
#  [                       0%                       ]  2 of 1000 complete
#  [                       0%                       ]  3 of 1000 complete
#  [                       0%                       ]  4 of 1000 complete
#  [                       1%                       ]  5 of 1000 complete
#  [                       1%                       ]  6 of 1000 complete
#  [                       1%                       ]  7 of 1000 complete
#  [                       1%                       ]  8 of 1000 complete
#  [                       1%                       ]  9 of 1000 complete
#  [                       1%                       ]  10 of 1000 complete
#  [                       1%                       ]  11 of 1000 complete
#  [                       1%                       ]  12 of 1000 complete
# ...

# %%
import os, csv

# %%
ls
# Out:
#  Volume in drive C is OS
#  Volume Serial Number is 2227-BAED
#
#  Directory of C:\allMYfiles\BOX\my_sandbox\learn_IPyNB
#
# 06/05/2014  07:37 PM    <DIR>          .
# 06/05/2014  07:37 PM    <DIR>          ..
# 06/05/2014  07:48 PM    <DIR>          .ipynb_checkpoints
# 06/05/2014  06:02 PM    <DIR>          EEG_Signal_Processing
# 06/05/2014  08:08 PM           998,055 general_tutorials.ipynb
# 06/05/2014  11:32 AM    <DIR>          IPyNB_example_Evolution-of-Swarming-Experiment
# 06/05/2014  08:10 PM             2,480 last_python_tutorial.ipynb
# 06/05/2014  03:27 PM             1,803 nb_from_canopy.ipynb
# 06/05/2014  04:43 PM            40,184 Untitled0.ipynb
# 06/05/2014  11:21 AM             2,459 Untitled0.py
#                5 File(s)      1,044,981 bytes
#                5 Dir(s)  72,940,335,104 bytes free

# %%
data=[]
#f=open(r'C:\allMYfiles\BOX\my_sandbox\learn_IPyNB\direct.csv','r')
#w=csv.reader(f)
for path, dirs, files in os.walk("C:\allMYfiles\BOX\my_sandbox\learn_IPyNB"):
    for filename in files:
        data.append([filename])

# %%
len(data)
# Out:
# 0

# %%
test=os.walk("C:\allMYfiles\BOX\my_sandbox\learn_IPyNB")
print(test)
# Out:
# <generator object walk at 0x0000000005D10CA8>

# %%
import os

with open("output.txt", "w") as a:
    for path, subdirs, files in os.walk(r'C:\allMYfiles\BOX\my_sandbox\learn_IPyNB'):
       for filename in files:
         f = os.path.join(path, filename)
         a.write(str(f) + os.linesep)

# %%
list=[]
for path, subdirs, files in os.walk(r'C:\allMYfiles\BOX\my_sandbox\learn_IPyNB'):
       for filename in files:
         list.append(filename)
         print(filename)
# Out:
# direct.csv
# general_tutorials.ipynb
# last_python_tutorial.ipynb
# nb_from_canopy.ipynb
# output.txt
# Untitled0.ipynb
# Untitled0.py
# general_tutorials-checkpoint.ipynb
# last_python_tutorial-checkpoint.ipynb
# nb_from_canopy-checkpoint.ipynb
# Untitled0-checkpoint.ipynb
# 1. Load EEG data and plot ERP.ipynb
# 2. Frequency analysis.ipynb
# 3. Imagined movement.ipynb
# 4. Classifying the P300.ipynb
# tutorial1-01.mat
# control1-fixed.csv
# control1.csv
# Evolution of Swarming Experiment.ipynb
# morph.png
# rso_stats.py
# rso_stats.pyc
# treatment1.csv
# treatment2.csv
# ._control1-fixed.csv
# ._control1.csv
# ._treatment1.csv
# ._treatment2.csv

# %%
import arcpy
from arcpy import env
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-45-52d618548e57> in <module>()
# ----> 1 import arcpy
#       2 from arcpy import env
#
# ImportError: No module named arcpy
